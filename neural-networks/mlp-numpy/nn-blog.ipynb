# %% [markdown]
# # Images and Diagrams for Blogs

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from fastbook import *

# %%
gv('''program[shape=box3d width=1 height=0.7]
inputs->program->results''')

# %%
gv('''model[shape=box3d width=1 height=0.7]
inputs->model->results; weights->model''')

# %%
gv('''ordering=in
model[shape=box3d width=1 height=0.7 label=architecture]
inputs->model->predictions; parameters->model; labels->loss; predictions->loss
loss->parameters[constraint=false label=update]''')

# %%
gv('''
x1->function[label=w1]; 
x2->function[label=w2];
x3->function[label=w3];
xn->function[label=wn]; 
function->y
''')

# %%
gv('''
x11->x21; x11->x22; x11->x23;  
x12->x21; x12->x22; x12->x23; 
x13->x21; x13->x22; x13->x23; 

x21->y
x22->y
x23->y
''')

# %%
def make_plot(x, f, name):
    plt.figure()
    plt.figure(figsize=(12,6))
    plt.title(name, fontsize=20, fontweight='bold')
    plt.xlabel('z', fontsize=15)
    plt.ylabel('Activation function value', fontsize=15)
    sns.set_style("whitegrid")
    plt.plot(x, f, label="f (z)")
    plt.legend(loc=4, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")
    plt.savefig(name + ".png")
    plt.show()

# %%
z = np.arange(-10, 10, 0.01)
f = 1/(1 + np.exp(-z))
make_plot(z, f, "Sigmoid")
